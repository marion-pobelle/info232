# %% [markdown]
# <div>
# <img src="logo.png", width=100, ALIGN="left">
# <center>
# <h1>Mini Projets 2019-2020 (Info 232)</h1>
# Isabelle Guyon <br>
# info232@chalearn.org <br>
# </center>
# <span style="color:red"> <h1> 2 . Pandas </h1> </span>
#
# We have now a dataset of pictures of REAL apples and bananas, preprocessed in 4 different representations:
# - one with only 2 features (<b>R</b>edness and <b>E</b>longation) called <b>RE_data.csv</b>
# - one with only 21 features (<b>C</b>olor and <b>S</b>hape features) called <b>CS_data.csv</b>
# - one with 14580 features (all pixels of 81x69x3 <b>raw</b> images) called <b>RAW_data.csv</b>
# - one with 3072 features (all pixels of 32x32x3 <b>crop</b>ped images) called <b>CROP_data.csv</b>.
#
# We will compare the performances of various classifiers on those 4 datasets. Thus, we are going to start doing "real" POM: Probability, Optimization, and Modeling. We will proceed in a "greedy" way, eliminating some non promising avenues as we go, and not revisiting them for the moment:
#
# 1. Which dataset version should we keep? Should we or not scale variables (using variable standardization)?
# 2. Which learning machine of a standard toolkit (scikit-learn) is most promising?
#
# </div>
# <div style="background:#FFFFAA">
#
#  This TP gives you 5 points if you answer well ALL 5 questions. If you cannot fisnish, get help by attending the Wednesday session.
#
# <span style="color:red"> <b>Save your notebook often with menu File + Save and Checkpoint.</b>
# <br> <b>Before you push your homework to your GitHub repo, use  Kernel + Restart and Run all.</b>
# </span>
#     </div>

# %%
# Load general libraries
import os, re
from glob import glob as ls
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

### Add path to the sample code so the notebook finds it:
code_dir = 'code/'                        
from sys import path; path.append(code_dir)
from utilities import *
# Import code that checks your answers
from checker import check 
# Disable some warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Step 1: Select data representation
# Which dataset version should we keep? Should we do or not a variable standardization?

# %% [markdown]
# ### Question 0: Examine the data directory
# Go to the directory `mini-dataset/`. You should find four data files ending with `.csv`. In an editor, open `RL_data.csv` or another of the data files to see how it looks like. The dataset is formatted in the CSV format (comma separated file). The examples are in lines and the features are separated by commas. The first line is the header.
#
# Examine all 4 datasets and note the number of lines and columns. Notice that they all have a different number of features but the same number of examples.
#
# It is somewhat easier to write a Python program to do this work for you. Check how the function `check_datasets` is written by typing `??check_datasets` in a new cell. Verify with an editor that this is the same code that is found in the directory `code/` in the file `utilities.py`.

# %%
# List the datasets
data_dir = './mini-dataset/'
data_list = ls(data_dir + '*_data.csv')
data_list
# Out:
# ['./mini-dataset/CROP_data.csv',
#  './mini-dataset/CS_data.csv',
#  './mini-dataset/RAW_data.csv',
#  './mini-dataset/RE_data.csv']

# %%
# Check the dataset sizes
check_datasets(data_list)
# Out:
#   Dataset  num. examples  num. features  num. apples  num. bananas
# 0    CROP            491           3073          333           158
# 1      CS            491             22          333           158
# 2     RAW            491          14581          333           158
# 3      RE            491              3          333           158

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Show the code of check_datasets.</b>

# %%
# Put your answer here
??check_datasets

# %% [markdown]
# ### Question 1: Load and visualize data with Pandas (review)
# In previous classes we have have started using `Numpy arrays`and `Pandas dataframes`. We now explore Pandas a little bit further. Pandas dataframes are also arrays, but a different kind of python object that Numpy arrays. They have more properties, supporting fancy database functions and having quite a few display functions and nice simple summary statistics, <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html">check the documentation</a>. Learning about Pandas will help a lot the <i>visualization binome</i>.
#
# First, you will perform these steps:
# * Call to UNIX command `!head ./mini-dataset/RE_data.csv` to view the first few lines of the file. The character `!` allows you to "escape" from the Jupyter notebook to the UNIX shell.
# * Load `RL_data.csv` as a pandas dataframe called `df`. Show the first few lines using the method `head`.
# * Compute simple statistics using the method `describe`.
# * Show the heat map. If you do not remember from the previous TP, think of using a search engine and type the keywords: "pandas heatmap". I found <a href="https://stackoverflow.com/questions/12286607/making-heatmap-from-pandas-dataframe">this post</a>, for instance.
# * Create a new data frame called `df_scaled` obtained by standardizing the columns of `df`. In the previous TP we used the method `StandardScaler` of `sklearn.preprocessing`. Notice that you can also simply compute the mean of `df` with `df.mean()` and the standard deviation with `df.std()`, then in one line of code get `df_scaled` by performing algebraic operations on dataframes!
# * We actually doe NOT want to standardize the <b>last column</b> (the class label). Make sure the last column of  `df_scaled` has the ORIGINAL label values +1 or -1.
#
# Then, the question you should answer to complete this section is: what are the mean and standard deviation of the lines and the columns of the `redness` and `elongation` features before and after standardization?

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Put here your call to the UNIX command "head".</b>

# %%
# Put your answer here
# !head ./mini-dataset/RE_data.csv
# Out:
# redness,elongation,fruit
# 8.429611650485437,1.4032012759326986,1.0
# 42.89607843137255,1.7032009898154288,1.0
# 56.354066985645936,1.5508105645577395,1.0
# -10.528846153846153,1.7773426521360935,1.0
# -17.131386861313867,2.047174441534352,1.0
# 36.041666666666664,1.4139561143744013,1.0
# 34.744932432432435,1.2379057682280559,1.0
# 1.8179190751445087,1.0839275628229141,1.0
# 3.34106529209622,1.0972000640347488,1.0

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Read file RE_data.csv as a dataframe and call it "df".</b>

# %%
data = pd.read_csv("./mini-dataset/RE_data.csv")
df = pd.DataFrame(data) # REPLACE THIS
df.head()
# Out:
#      redness  elongation  fruit
# 0   8.429612    1.403201    1.0
# 1  42.896078    1.703201    1.0
# 2  56.354067    1.550811    1.0
# 3 -10.528846    1.777343    1.0
# 4 -17.131387    2.047174    1.0

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Show descriptive statistics with the method "describe".</b>

# %%
# Put your answer here
df.describe()
# Out:
#           redness  elongation       fruit
# count  491.000000  491.000000  491.000000
# mean    17.863426    1.468878    0.356415
# std     21.805386    0.521078    0.935280
# min    -47.045455    1.000000   -1.000000
# 25%      3.895620    1.161664   -1.000000
# 50%     14.380952    1.300111    1.000000
# 75%     33.848108    1.598103    1.000000
# max    100.364865    5.231697    1.000000

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Show the heat map of "df".</b>

# %%
plt.pcolor(df)
plt.yticks(np.arange(0.5, len(df.index), 1), df.index)
plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns)
plt.show()

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Standardize the columns of "df", EXCEPT THE LAST ONE.</b>

# %%
# Put your code here
df_scaled = df
df_scaled.iloc[:, :-1] = (df.iloc[:,:-1]-df.iloc[:,:-1].mean())/df.iloc[:,:-1].std() # REPLACE THIS

# %%
df_scaled.describe()
# Out:
#             redness    elongation       fruit
# count  4.910000e+02  4.910000e+02  491.000000
# mean  -1.085350e-16 -8.266752e-16    0.356415
# std    1.000000e+00  1.000000e+00    0.935280
# min   -2.976736e+00 -8.998221e-01   -1.000000
# 25%   -6.405668e-01 -5.895726e-01   -1.000000
# 50%   -1.597070e-01 -3.238798e-01    1.000000
# 75%    7.330612e-01  2.479972e-01    1.000000
# max    3.783535e+00  7.221221e+00    1.000000

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Your final answers to question 1. </b> What are the mean and standard deviation of the lines and the columns of the `redness` and `elongation` features before and after standardization?

# %%
question = 1
score = 0
# Put your answers to question 1 here
redness_mean_before, elongation_mean_before, label_mean_before = 17.863426, 1.468878, 0.356415
redness_std_before, elongation_std_before, label_std_before = 21.805386, 0.521078, 0.935280
redness_mean_after, elongation_mean_after, label_mean_after = -1.085350e-16	, -8.266752e-16, 0.356415
redness_std_after, elongation_std_after, label_std_after = 1.000000e+00, 1.000000e+00, 0.935280

# This is the checker code, keep it
answer = redness_mean_before+elongation_mean_before+label_mean_before
answer += redness_std_before+elongation_std_before+label_std_before
answer -= redness_mean_after+elongation_mean_after+label_mean_after
answer -= redness_std_after+elongation_std_after+label_std_after
score += check(answer, question)
# Out:
# 39.658768
# 39.6587674942419
# <div style="background:#00FF00">CORRECT<br>:-)</div>

# %% [markdown]
# ### Question 2: Write a function to standardize data
# It is often useful to `standardize` the columns of the data matrix to put all values in a similar scale, so to facilitate re-using this operation, write a function that takes as input a data frame `df` containing a dataset and returns a dataframe `df_scaled` with the columns standardized <b>EXCEPT THE TARGET VALUES</b> of the last column (use your answers to the previous section). Use this template for your code:
#
#     def standardize_df(df):
#     '''Standardize all the columns except the last one (target values).'''
#     # YOUR CODE HERE
#     return df_scaled
#
# Test your function with the same dataframe as in the previous questions and use the methods `head` and `describe` to verify that all the columns are standardized, except the last one. Notice that, due to machine precision, you may not get exactly mean=0 and std=1.

# %%
# Replace by your own code:
def standardize_df(df):
    '''Standardize all the columns except the last one (target values).'''
    df_scaled = df
    df_scaled.iloc[:, :-1] = (df.iloc[:,:-1]-df.iloc[:,:-1].mean())/df.iloc[:,:-1].std() # REPLACE THIS
    return df_scaled

df_scaled2 = standardize_df(df)
df_scaled2.head()
# Out:
#     redness  elongation  fruit
# 0 -0.432637   -0.126039    1.0
# 1  1.148003    0.449690    1.0
# 2  1.765190    0.157238    1.0
# 3 -1.302076    0.591975    1.0
# 4 -1.604870    1.109809    1.0

# %%
df_scaled2.describe()
# Out:
#             redness    elongation       fruit
# count  4.910000e+02  4.910000e+02  491.000000
# mean  -4.793631e-17 -1.211975e-16    0.356415
# std    1.000000e+00  1.000000e+00    0.935280
# min   -2.976736e+00 -8.998221e-01   -1.000000
# 25%   -6.405668e-01 -5.895726e-01   -1.000000
# 50%   -1.597070e-01 -3.238798e-01    1.000000
# 75%    7.330612e-01  2.479972e-01    1.000000
# max    3.783535e+00  7.221221e+00    1.000000

# %%
# This is the checker code, keep it
question = 2
answer = (df_scaled == df_scaled2).all().all()
score += check(answer, question)
# Out:
# True
# 1
# <div style="background:#00FF00">CORRECT<br>:-)</div>

# %% [markdown]
# ### Question 3: Select the best representation
# We are now going to loop over all datasets and compare the performance of our baseline method (one nearest neighbor classifier) with and without variable scaling.
#
# First you will perform these steps (with some help):
# * Import `KNeighborsClassifier` from the scikit-learn library (`sklearn`) and instanciate a one nearest neighbor classifier that you will call `sklearn_model`. Also import the `balanced_accuracy_score` and name it `sklearn_metric`.
# * Call `df_cross_validate(df, sklearn_model, sklearn_metric)` and collect the results, then print the training and test performance and their error bars. <b>Tip:</b> look at the bottom of the code using `??df_cross_validate` to get an idea on how to print the results.
# * Create:
#  * a list containing all the dataset dataframes and call it `all_data_df`
#  * a list containg all the dataset names and call it `data_name`.
# * Run the function `systematic_data_experiment(data_name, all_scaled_data_df, sklearn_model, sklearn_metric)` and display the results.
# * <b>Create a list</b> containing all the SCALED datasets (variables standardized) and call it `all_scaled_data_df`.
# * Run again `systematic_data_experiment` on `all_scaled_data_df` and display the results.
# * Fuse the results of the two previous question by creating a dataframe called `joint_results`. Assign `result_scaling.perf_te` to a column called `'SCALED'` and `result_noscaling.perf_te` to a column called `'NOT SCALED'`. Display the results.
# * Visualize `joint_results` with a histogram. Check <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html">this documentation</a>.
#
# Then the questions you should answer are:
# * Does re-scaling variables always help?
# * Is which case does it help most?
#
# Try to reason why this might be.

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Make necessary changes; USE THE DOCUMENTATION OF SCIKIT LEARN (do not copy on your neighbor).</b>

# %%
from sklearn.neighbors import KNeighborsClassifier as KNei
from sklearn.metrics import balanced_accuracy_score as sklearn_metric
sklearn_model = KNei() # Replace by ONE nearest neighbor

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Collect the results of df_cross_validate(df, sklearn_model, sklearn_metric).</b>

# %%
??df_cross_validate
p_te, s_te, p_tr, s_tr  = df_cross_validate(df, sklearn_model, sklearn_metric)

metric_name = sklearn_metric.__name__.upper()
print("AVERAGE TRAINING {0:s} +- STD: {1:.2f} +- {2:.2f}".format(metric_name, p_tr, s_tr))
print("AVERAGE TEST {0:s} +- STD: {1:.2f} +- {2:.2f}".format(metric_name, p_te, s_te))
# Out:
# AVERAGE TRAINING BALANCED_ACCURACY_SCORE +- STD: 0.69 +- 0.02
# AVERAGE TEST BALANCED_ACCURACY_SCORE +- STD: 0.76 +- 0.03

# %%
# We give you this code, read it and try to understand it
data_name = [os.path.basename(file)[:-9] for file in data_list]
all_data_df = [pd.read_csv(file) for file in data_list]
print('NO SCALING')
result_noscaling = systematic_data_experiment(data_name, all_data_df, sklearn_model, sklearn_metric)
result_noscaling.style.background_gradient(cmap='Blues')
# Out:
# NO SCALING
# KNEIGHBORSCLASSIFIER
# <style  type="text/css" >
#     #T_1911fd00_4407_11ea_9f45_782bcba27d83row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1911fd00_4407_11ea_9f45_782bcba27d83row0_col1 {
#             background-color:  #084c95;
#             color:  #f1f1f1;
#         }    #T_1911fd00_4407_11ea_9f45_782bcba27d83row0_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1911fd00_4407_11ea_9f45_782bcba27d83row0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1911fd00_4407_11ea_9f45_782bcba27d83row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1911fd00_4407_11ea_9f45_782bcba27d83row1_col1 {
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }    #T_1911fd00_4407_11ea_9f45_782bcba27d83row1_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1911fd00_4407_11ea_9f45_782bcba27d83row1_col3 {
#             background-color:  #75b4d8;
#             color:  #000000;
#         }    #T_1911fd00_4407_11ea_9f45_782bcba27d83row2_col0 {
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }    #T_1911fd00_4407_11ea_9f45_782bcba27d83row2_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1911fd00_4407_11ea_9f45_782bcba27d83row2_col2 {
#             background-color:  #85bcdc;
#             color:  #000000;
#         }    #T_1911fd00_4407_11ea_9f45_782bcba27d83row2_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1911fd00_4407_11ea_9f45_782bcba27d83row3_col0 {
#             background-color:  #08316d;
#             color:  #f1f1f1;
#         }    #T_1911fd00_4407_11ea_9f45_782bcba27d83row3_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1911fd00_4407_11ea_9f45_782bcba27d83row3_col2 {
#             background-color:  #083979;
#             color:  #f1f1f1;
#         }    #T_1911fd00_4407_11ea_9f45_782bcba27d83row3_col3 {
#             background-color:  #cddff1;
#             color:  #000000;
#         }</style><table id="T_1911fd00_4407_11ea_9f45_782bcba27d83" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >perf_tr</th>        <th class="col_heading level0 col1" >std_tr</th>        <th class="col_heading level0 col2" >perf_te</th>        <th class="col_heading level0 col3" >std_te</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1911fd00_4407_11ea_9f45_782bcba27d83level0_row0" class="row_heading level0 row0" >CROP</th>
#                         <td id="T_1911fd00_4407_11ea_9f45_782bcba27d83row0_col0" class="data row0 col0" >0.741231</td>
#                         <td id="T_1911fd00_4407_11ea_9f45_782bcba27d83row0_col1" class="data row0 col1" >0.0256676</td>
#                         <td id="T_1911fd00_4407_11ea_9f45_782bcba27d83row0_col2" class="data row0 col2" >0.664129</td>
#                         <td id="T_1911fd00_4407_11ea_9f45_782bcba27d83row0_col3" class="data row0 col3" >0.027659</td>
#             </tr>
#             <tr>
#                         <th id="T_1911fd00_4407_11ea_9f45_782bcba27d83level0_row1" class="row_heading level0 row1" >CS</th>
#                         <td id="T_1911fd00_4407_11ea_9f45_782bcba27d83row1_col0" class="data row1 col0" >0.687468</td>
#                         <td id="T_1911fd00_4407_11ea_9f45_782bcba27d83row1_col1" class="data row1 col1" >0.0218594</td>
#                         <td id="T_1911fd00_4407_11ea_9f45_782bcba27d83row1_col2" class="data row1 col2" >0.537948</td>
#                         <td id="T_1911fd00_4407_11ea_9f45_782bcba27d83row1_col3" class="data row1 col3" >0.0235053</td>
#             </tr>
#             <tr>
#                         <th id="T_1911fd00_4407_11ea_9f45_782bcba27d83level0_row2" class="row_heading level0 row2" >RAW</th>
#                         <td id="T_1911fd00_4407_11ea_9f45_782bcba27d83row2_col0" class="data row2 col0" >0.691029</td>
#                         <td id="T_1911fd00_4407_11ea_9f45_782bcba27d83row2_col1" class="data row2 col1" >0.0263476</td>
#                         <td id="T_1911fd00_4407_11ea_9f45_782bcba27d83row2_col2" class="data row2 col2" >0.592807</td>
#                         <td id="T_1911fd00_4407_11ea_9f45_782bcba27d83row2_col3" class="data row2 col3" >0.0197732</td>
#             </tr>
#             <tr>
#                         <th id="T_1911fd00_4407_11ea_9f45_782bcba27d83level0_row3" class="row_heading level0 row3" >RE</th>
#                         <td id="T_1911fd00_4407_11ea_9f45_782bcba27d83row3_col0" class="data row3 col0" >0.740861</td>
#                         <td id="T_1911fd00_4407_11ea_9f45_782bcba27d83row3_col1" class="data row3 col1" >0.0201075</td>
#                         <td id="T_1911fd00_4407_11ea_9f45_782bcba27d83row3_col2" class="data row3 col2" >0.659592</td>
#                         <td id="T_1911fd00_4407_11ea_9f45_782bcba27d83row3_col3" class="data row3 col3" >0.0214735</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# What do you observe by comparing the accuracy on training data and on test data?

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Compute all_scaled_data_df in a one-line formula. Imitate the code in the previous cell.</b>

# %%
all_scaled_data_df = [standardize_df(pd.read_csv(file)) for file in data_list] # CHANGE THIS!

print('WITH SCALING')
result_scaling = systematic_data_experiment(data_name, all_scaled_data_df, sklearn_model, sklearn_metric)
result_scaling.style.background_gradient(cmap='Blues')
# Out:
# WITH SCALING
# KNEIGHBORSCLASSIFIER
# <style  type="text/css" >
#     #T_43012d02_4407_11ea_9f45_782bcba27d83row0_col0 {
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }    #T_43012d02_4407_11ea_9f45_782bcba27d83row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_43012d02_4407_11ea_9f45_782bcba27d83row0_col2 {
#             background-color:  #bed8ec;
#             color:  #000000;
#         }    #T_43012d02_4407_11ea_9f45_782bcba27d83row0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_43012d02_4407_11ea_9f45_782bcba27d83row1_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_43012d02_4407_11ea_9f45_782bcba27d83row1_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_43012d02_4407_11ea_9f45_782bcba27d83row1_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_43012d02_4407_11ea_9f45_782bcba27d83row1_col3 {
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }    #T_43012d02_4407_11ea_9f45_782bcba27d83row2_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_43012d02_4407_11ea_9f45_782bcba27d83row2_col1 {
#             background-color:  #4997c9;
#             color:  #000000;
#         }    #T_43012d02_4407_11ea_9f45_782bcba27d83row2_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_43012d02_4407_11ea_9f45_782bcba27d83row2_col3 {
#             background-color:  #97c6df;
#             color:  #000000;
#         }    #T_43012d02_4407_11ea_9f45_782bcba27d83row3_col0 {
#             background-color:  #8dc1dd;
#             color:  #000000;
#         }    #T_43012d02_4407_11ea_9f45_782bcba27d83row3_col1 {
#             background-color:  #5ca4d0;
#             color:  #000000;
#         }    #T_43012d02_4407_11ea_9f45_782bcba27d83row3_col2 {
#             background-color:  #77b5d9;
#             color:  #000000;
#         }    #T_43012d02_4407_11ea_9f45_782bcba27d83row3_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }</style><table id="T_43012d02_4407_11ea_9f45_782bcba27d83" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >perf_tr</th>        <th class="col_heading level0 col1" >std_tr</th>        <th class="col_heading level0 col2" >perf_te</th>        <th class="col_heading level0 col3" >std_te</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_43012d02_4407_11ea_9f45_782bcba27d83level0_row0" class="row_heading level0 row0" >CROP</th>
#                         <td id="T_43012d02_4407_11ea_9f45_782bcba27d83row0_col0" class="data row0 col0" >0.708411</td>
#                         <td id="T_43012d02_4407_11ea_9f45_782bcba27d83row0_col1" class="data row0 col1" >0.0345266</td>
#                         <td id="T_43012d02_4407_11ea_9f45_782bcba27d83row0_col2" class="data row0 col2" >0.640249</td>
#                         <td id="T_43012d02_4407_11ea_9f45_782bcba27d83row0_col3" class="data row0 col3" >0.0309496</td>
#             </tr>
#             <tr>
#                         <th id="T_43012d02_4407_11ea_9f45_782bcba27d83level0_row1" class="row_heading level0 row1" >CS</th>
#                         <td id="T_43012d02_4407_11ea_9f45_782bcba27d83row1_col0" class="data row1 col0" >0.865819</td>
#                         <td id="T_43012d02_4407_11ea_9f45_782bcba27d83row1_col1" class="data row1 col1" >0.0197294</td>
#                         <td id="T_43012d02_4407_11ea_9f45_782bcba27d83row1_col2" class="data row1 col2" >0.808857</td>
#                         <td id="T_43012d02_4407_11ea_9f45_782bcba27d83row1_col3" class="data row1 col3" >0.0179036</td>
#             </tr>
#             <tr>
#                         <th id="T_43012d02_4407_11ea_9f45_782bcba27d83level0_row2" class="row_heading level0 row2" >RAW</th>
#                         <td id="T_43012d02_4407_11ea_9f45_782bcba27d83row2_col0" class="data row2 col0" >0.68775</td>
#                         <td id="T_43012d02_4407_11ea_9f45_782bcba27d83row2_col1" class="data row2 col1" >0.0286679</td>
#                         <td id="T_43012d02_4407_11ea_9f45_782bcba27d83row2_col2" class="data row2 col2" >0.576211</td>
#                         <td id="T_43012d02_4407_11ea_9f45_782bcba27d83row2_col3" class="data row2 col3" >0.0215136</td>
#             </tr>
#             <tr>
#                         <th id="T_43012d02_4407_11ea_9f45_782bcba27d83level0_row3" class="row_heading level0 row3" >RE</th>
#                         <td id="T_43012d02_4407_11ea_9f45_782bcba27d83row3_col0" class="data row3 col0" >0.761846</td>
#                         <td id="T_43012d02_4407_11ea_9f45_782bcba27d83row3_col1" class="data row3 col1" >0.0277645</td>
#                         <td id="T_43012d02_4407_11ea_9f45_782bcba27d83row3_col2" class="data row3 col2" >0.685754</td>
#                         <td id="T_43012d02_4407_11ea_9f45_782bcba27d83row3_col3" class="data row3 col3" >0.0154194</td>
#             </tr>
#     </tbody></table>

# %%
# This is how to collect the test results in a single dataframe
joint_results = pd.DataFrame()
joint_results['SCALED'] = result_scaling.perf_te
joint_results['NOT SCALED'] = result_noscaling.perf_te
joint_results
# Out:
#         SCALED  NOT SCALED
# CROP  0.640249    0.664129
# CS    0.808857    0.537948
# RAW   0.576211    0.592807
# RE    0.685754    0.659592

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Put here the code to plot "joint_results" as a bar graph. Check the <a href="Check https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html"> documentation</a></b>.

# %%
joint_results.plot.bar() # REPLACE THIS!
plt.ylabel(sklearn_metric.__name__)
# Out:
# Text(0, 0.5, 'balanced_accuracy_score')

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Your final answers to question 3:</a></b> Does rescaling always help? In which case does it help most?

# %%
# Put your answer to question 3 here
rescaling_always_help = 0 # 0 for false, 1 for true
varnum_rescaling_helps_most = 1 # num of var (0-based) for which perf. improve most after rescaling
case_num_rescaling_helps_most = 1 # num of case (0-based) for which perf. improve most after rescaling

# This is the checker code, keep it
question = 3
answer = (p_tr+s_tr+p_te+s_te)/10
answer += joint_results.sum().sum()/10-rescaling_always_help-case_num_rescaling_helps_most
score += check(answer, question)
# Out:
# -0.3175988345397004
# -1.3145198580879243
# <div style="background:#FF0000">BOOOOH<br>:-(</div>

# %% [markdown]
# ## Step 2: Identify the best model
# We are now ready to perform systematic experiments on various models. We will use the methods proposed in the variable `classifiers` of <a href="https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html">these scikit-learn examples</a>, compare classifier performances on the dataset `CS_SCALED`:
#
# ### Question 4: Overfitting and underfitting
#
# </b> There may be two reasons why a model performs poorly. It could either be <b>overfitting</b> or <b>underfitting</b> data.
#
# First you will perform these steps (with some help):
#
# * Create a variable `data_df` and assign to it the data frame of the scaled version of the CS dataset.
# * Create a variable `model_name` and a variable `model_list` containing the list of model names and the list of models (classifiers) from the <a href="https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html">the scikit-learn examples</a> we pointed you to.
# * Call `systematic_model_experiment(data_df, model_name, model_list, sklearn_metric)` and display the results.
# * Find which method performs best. <b>Tip:</b> Use <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.idxmax.html#pandas.Series.idxmax">idxmax</a>.
# * Find which models have TEST performance UNDER THE MEDIAN test performance. The single out models with TRAINING performance UNDER THE MEDIAN and those with TRAINING performance OVER THE MEDIAN.
#
# Then answer those questions:
# * If the test performance is bad but the training performance is good, is the model under-fitting or over-fitting?
# * If both are bad, is the model is under-fitting or over-fitting?
# * Which models are over-fitted and which ones are under-fitted?

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Choose the correct dataset: CS representation, scaled data.</b>

# %%
dataset_choice = 1 # Change that
data_df = all_scaled_data_df[dataset_choice] # Change that

print(data_df.shape)
# Out:
# (491, 22)

# %% [markdown]
# #### Classifier comparison
# We import a bunch of classifiers, inspired
# by <a href="https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html">that list</a>.

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

model_name = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Gaussian Process",
         "Decision Tree", "Random Forest", "Neural Net", "AdaBoost",
         "Naive Bayes", "QDA"]
model_list = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    SVC(gamma=2, C=1),
    GaussianProcessClassifier(1.0 * RBF(1.0)),
    DecisionTreeClassifier(max_depth=10),
    RandomForestClassifier(max_depth=10, n_estimators=10, max_features=1),
    MLPClassifier(alpha=1, max_iter=1000),
    AdaBoostClassifier(),
    GaussianNB(),
    QuadraticDiscriminantAnalysis()]

# %% [markdown]
# #### Systematic experiments:
# We give you this code to make systematic experiments (run all models on the chosen representation). You may get a warning. What could explain it?

# %%
compar_results = systematic_model_experiment(data_df, model_name, model_list, sklearn_metric)
compar_results.round(2).style.background_gradient(cmap='Blues')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# <style  type="text/css" >
#     #T_4e703c4a_4408_11ea_9f45_782bcba27d83row0_col0 {
#             background-color:  #82bbdb;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row0_col1 {
#             background-color:  #abd0e6;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row0_col2 {
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row0_col3 {
#             background-color:  #4a98c9;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row1_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row1_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row1_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row1_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row2_col0 {
#             background-color:  #083573;
#             color:  #f1f1f1;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row2_col1 {
#             background-color:  #abd0e6;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row2_col2 {
#             background-color:  #084d96;
#             color:  #f1f1f1;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row2_col3 {
#             background-color:  #4a98c9;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row3_col0 {
#             background-color:  #083573;
#             color:  #f1f1f1;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row3_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row3_col2 {
#             background-color:  #083979;
#             color:  #f1f1f1;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row3_col3 {
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row4_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row4_col1 {
#             background-color:  #105ba4;
#             color:  #f1f1f1;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row4_col2 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row4_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row5_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row5_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row5_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row5_col3 {
#             background-color:  #94c4df;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row6_col0 {
#             background-color:  #82bbdb;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row6_col1 {
#             background-color:  #abd0e6;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row6_col2 {
#             background-color:  #0c56a0;
#             color:  #f1f1f1;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row6_col3 {
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row7_col0 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row7_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row7_col2 {
#             background-color:  #dae8f6;
#             color:  #000000;
#         }    #T_4e703c4a_4408_11ea_9f45_782bcba27d83row7_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }</style><table id="T_4e703c4a_4408_11ea_9f45_782bcba27d83" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >perf_tr</th>        <th class="col_heading level0 col1" >std_tr</th>        <th class="col_heading level0 col2" >perf_te</th>        <th class="col_heading level0 col3" >std_te</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4e703c4a_4408_11ea_9f45_782bcba27d83level0_row0" class="row_heading level0 row0" >Nearest Neighbors</th>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row0_col0" class="data row0 col0" >0.75</td>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row0_col1" class="data row0 col1" >0.02</td>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row0_col2" class="data row0 col2" >0.52</td>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row0_col3" class="data row0 col3" >0.03</td>
#             </tr>
#             <tr>
#                         <th id="T_4e703c4a_4408_11ea_9f45_782bcba27d83level0_row1" class="row_heading level0 row1" >Linear SVM</th>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row1_col2" class="data row1 col2" >0.51</td>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row1_col3" class="data row1 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_4e703c4a_4408_11ea_9f45_782bcba27d83level0_row2" class="row_heading level0 row2" >RBF SVM</th>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row2_col0" class="data row2 col0" >0.99</td>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row2_col1" class="data row2 col1" >0.02</td>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row2_col2" class="data row2 col2" >0.75</td>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row2_col3" class="data row2 col3" >0.03</td>
#             </tr>
#             <tr>
#                         <th id="T_4e703c4a_4408_11ea_9f45_782bcba27d83level0_row3" class="row_heading level0 row3" >Gaussian Process</th>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row3_col0" class="data row3 col0" >0.99</td>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row3_col1" class="data row3 col1" >0</td>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row3_col2" class="data row3 col2" >0.77</td>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row3_col3" class="data row3 col3" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_4e703c4a_4408_11ea_9f45_782bcba27d83level0_row4" class="row_heading level0 row4" >Decision Tree</th>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row4_col0" class="data row4 col0" >0.55</td>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row4_col1" class="data row4 col1" >0.05</td>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row4_col2" class="data row4 col2" >0.54</td>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782bcba27d83row4_col3" class="data row4 col3" >0.05</td>
#             </tr>
#             <tr>
#                         <th id="T_4e703c4a_4408_11ea_9f45_782bcba27d83level0_row5" class="row_heading level0 row5" >Random Forest</th>
#                         <td id="T_4e703c4a_4408_11ea_9f45_782

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Find the method performing best on test data.</b>

# %%
# Find the method performing best on test data
best_method = "Nearest Neighbors" # REPLACE THIS; try not to just do this by hand, apply idxmax to the series perf_te
print("Best method: {}".format(best_method))
# Out:
# Best method: Nearest Neighbors

# %% [markdown]
# #### Over-fitting and under-fitting
# There may be two reasons why a model performs poorly. It could either be <b>over-fitting</b> or <b>under-fitting</b> data. Under-fitting means that the model is not powerful enough to even learn the training data while over-fitting means that the model is so powerful that it can learn super-well the training data, but it might not generalize well to new test data.
#
# Of the models performing poorly (having TEST performance UNDER THE MEDIAN test performance), we highlight:
# * models with TRAINING performance UNDER THE MEDIAN training performance (<b>under-fitted</b>)
# * models with TRAINING performance OVER THE MEDIAN (<b>over-fitted</b>)

# %%
# We give you this code, check it in utilities.py of use ??analyze_model_experiments
analyze_model_experiments(compar_results)
# Out:
# <style  type="text/css" >
#     #T_5f8bc742_4408_11ea_9f45_782bcba27d83row0_col3 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row0_col5 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row1_col0 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row1_col4 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row2_col0 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row2_col1 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row2_col2 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row2_col3 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row3_col0 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row3_col2 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row4_col1 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row4_col3 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row4_col5 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row5_col0 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row5_col2 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row6_col1 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row6_col2 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row7_col1 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row7_col3 {
#             background-color:  yellow;
#         }    #T_5f8bc742_4408_11ea_9f45_782bcba27d83row7_col5 {
#             background-color:  yellow;
#         }</style><table id="T_5f8bc742_4408_11ea_9f45_782bcba27d83" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >perf_tr</th>        <th class="col_heading level0 col1" >std_tr</th>        <th class="col_heading level0 col2" >perf_te</th>        <th class="col_heading level0 col3" >std_te</th>        <th class="col_heading level0 col4" >Overfitted</th>        <th class="col_heading level0 col5" >Underfitted</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5f8bc742_4408_11ea_9f45_782bcba27d83level0_row0" class="row_heading level0 row0" >Nearest Neighbors</th>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row0_col0" class="data row0 col0" >0.750034</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row0_col1" class="data row0 col1" >0.015313</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row0_col2" class="data row0 col2" >0.524517</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row0_col3" class="data row0 col3" >0.0277645</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row0_col4" class="data row0 col4" >False</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row0_col5" class="data row0 col5" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_5f8bc742_4408_11ea_9f45_782bcba27d83level0_row1" class="row_heading level0 row1" >Linear SVM</th>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row1_col2" class="data row1 col2" >0.506818</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row1_col3" class="data row1 col3" >0.00433264</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row1_col4" class="data row1 col4" >True</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row1_col5" class="data row1 col5" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5f8bc742_4408_11ea_9f45_782bcba27d83level0_row2" class="row_heading level0 row2" >RBF SVM</th>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row2_col0" class="data row2 col0" >0.987464</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row2_col1" class="data row2 col1" >0.0176867</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row2_col2" class="data row2 col2" >0.751262</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row2_col3" class="data row2 col3" >0.0348471</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row2_col4" class="data row2 col4" >False</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row2_col5" class="data row2 col5" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5f8bc742_4408_11ea_9f45_782bcba27d83level0_row3" class="row_heading level0 row3" >Gaussian Process</th>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row3_col0" class="data row3 col0" >0.985203</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row3_col1" class="data row3 col1" >0.00395063</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row3_col2" class="data row3 col2" >0.774649</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row3_col3" class="data row3 col3" >0.0124032</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row3_col4" class="data row3 col4" >False</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row3_col5" class="data row3 col5" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5f8bc742_4408_11ea_9f45_782bcba27d83level0_row4" class="row_heading level0 row4" >Decision Tree</th>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row4_col0" class="data row4 col0" >0.549306</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row4_col1" class="data row4 col1" >0.0519265</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row4_col2" class="data row4 col2" >0.537573</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row4_col3" class="data row4 col3" >0.0451756</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row4_col4" class="data row4 col4" >False</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row4_col5" class="data row4 col5" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_5f8bc742_4408_11ea_9f45_782bcba27d83level0_row5" class="row_heading level0 row5" >Random Forest</th>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row5_col0" class="data row5 col0" >0.999398</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row5_col1" class="data row5 col1" >0.00180723</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row5_col2" class="data row5 col2" >0.782627</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row5_col3" class="data row5 col3" >0.0242981</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row5_col4" class="data row5 col4" >False</td>
#                         <td id="T_5f8bc742_4408_11ea_9f45_782bcba27d83row5_col5" class="data row5 col5" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5f8bc742_4408_11ea_9f45_782bcba27d83level0_row6" class="row_heading level0 row6" >Neural Net</th>

# %%
??analyze_model_experiments

# %% [markdown]
# #### Bar graph comparing  results

# %%
compar_results[['perf_tr', 'perf_te']].plot.bar()
plt.ylim(0.5, 1)
plt.ylabel(sklearn_metric.__name__)
# Out:
# Text(0, 0.5, 'balanced_accuracy_score')

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Your final answers to question 4:</a> </b>Which methods overfits or underfit?</b>

# %%
# Put your answer to question 4 here
#If the test performance is bad but the training performance is good, is the model under-fitting or over-fitting?
answer1 = 1 # 0 for under-fitting and 1 for over-fitting
#If both are bad, is the model is under-fitting or over-fitting? 
answer2 = 0 # 0 for under-fitting and 1 for over-fitting
# Which models are over-fitted and which ones are under-fitted?
overfitted_list = [2,4,5] # Replace by the correct numbers in model_name
underfitted_list = [1,8] # Replace by the correct numbers in model_name

model_name = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Gaussian Process",
         "Decision Tree", "Random Forest", "Neural Net", "AdaBoost",
         "Naive Bayes", "QDA"]

print("Over_fitted models:")
print([model_name[i] for i in overfitted_list])
print("Under_fitted models:")
print([model_name[i] for i in underfitted_list])
# This is the checker code, keep it
question = 4
answer = answer1-answer2+sum(overfitted_list)-sum(underfitted_list)+model_name.index(best_method)

score += check(answer, question)
# Out:
# Over_fitted models:
# ['RBF SVM', 'Decision Tree', 'Random Forest']
# Under_fitted models:
# ['Linear SVM', 'Naive Bayes']
# 3
# 3
# <div style="background:#00FF00">CORRECT<br>:-)</div>

# %% [markdown]
# ###  Question 5: Dimensionality reduction
# It is useful to reduce the data dimension (number of features) for two reasons: ease of visualisation and possibly increase in performance. Two approaches are possible:
# 1. Feature selection.
# 1. Feature transforms.
#
# In the first case, one tries to select among the original features. In the second case, one first replaces the original features by "combinations" of features, then perform selection. Here we give two simple examples: Feature ranking with the <b>Pearson correlation</b> coefficient (as a feature selection method), and <b>Singular Value Decomposition</b> or SVD (as a feature transform method) .
#
# In this section, we keep using the <b>CS scaled data</b>. We use as classifier the <b>3-nearest-neighbor</b> model, which seems to have served us well! We begin by showing you how to do simple feature selection, then we'll guide you step-by-step through SVD.

# %% [markdown]
# ### Feature selection example
# We perform feature selection with the Pearson correlation coefficient as follows:
# * Compute the correlation matrix (we will only use the last column, i.e. correlation of features with the class label to be predicted)
# * Sort the correlation coefficients (of features and class label)

# %% [markdown]
# #### Correlation matrix
# If we did things right, `data_df` should contain the CS data.

# %%
corr = data_df.corr()
corr.round(1).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col1 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col2 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col3 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col4 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col5 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col6 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col7 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col8 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col9 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col10 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col11 {
#             background-color:  #f18d6f;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col12 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col13 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col14 {
#             background-color:  #f18d6f;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col15 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col16 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col17 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col18 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col19 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col20 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row0_col21 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col0 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col2 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col3 {
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col4 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col5 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col6 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col7 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col8 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col9 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col10 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col11 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col12 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col13 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col14 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col15 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col16 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col17 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col18 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col19 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col20 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row1_col21 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row2_col0 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row2_col1 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row2_col3 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row2_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row2_col5 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row2_col6 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row2_col7 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row2_col8 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row2_col9 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row2_col10 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row2_col11 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row2_col12 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row2_col13 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row2_col14 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_802729ec_4408_11ea_9f45_782bcba27d83row2_col15 {
#             background-color:  #e97a5f;

# %% [markdown]
# #### Sort features

# %% [markdown]
# Let us first sort all features by the <b>absolute value</b> of the Pearson correlation coefficient. Indeed, variables are informative no matter whether they are correlated or anti-correlated (since it suffices to multiply them by -1 to change the correlation direction).

# %%
sval = corr['fruit'][:-1].abs().sort_values(ascending=False)
ranked_columns = sval.index.values
print(ranked_columns)
# Out:
# ['R' '(B-R)/C' 'R-(G+B)/2' 'B-R' 'W/H' '(R+G+B)/3' 'R-G' 'B-(G+R)/2'
#  '(R-G)/C' 'M=maxRGB' '(G-B)/C' 'G' 'H' 'G-B' 'W' 'G-(R+B)/2' 'W*H'
#  'C=M-m' 'm=minRGB' 'C/V' 'B']

# %% [markdown]
# We notice that the features that we have constructed in the previous lessons 'R-(G+B)/2' and 'W/H' come in the 5 top most informative features. But there are others. Let us make all scatter plots of pairs of features for the 5 top ranked features.

# %% [markdown]
# #### Visualize top 5 features with PAIRPLOT

# %%
# Make a dataframe with only top five features
fruit_name = ['Banana', 'Apple']
fruit_list = [fruit_name[int((i+1)/2)] for i in data_df["fruit"].tolist()]
col_selected = ranked_columns[0:5]
df_5feat = pd.DataFrame.copy(data_df)
df_5feat = df_5feat[col_selected]
df_5feat['fruit'] = fruit_list
df_5feat.head()
# Out:
#             R   (B-R)/C  R-(G+B)/2        B-R       W/H  fruit
# 0  200.631068 -0.447698   8.429612  -9.723301  1.403201  Apple
# 1  212.400000 -0.793911  42.896078 -67.498039  1.703201  Apple
# 2  203.693780 -0.956824  56.354067 -90.518341  1.550811  Apple
# 3  168.534615 -0.306394 -10.528846 -22.061538  1.777343  Apple
# 4  201.299270 -0.049887 -17.131387  -2.248175  2.047174  Apple

# %%
# Show pairplot
g = sns.pairplot(df_5feat, hue="fruit", markers=["o", "s"], diag_kind="hist")

# %% [markdown]
# #### Learning curves
# We want to eveluate the effect of varying the number of features. To that end, we build learning curves = performance as a function of feature number.

# %%
# We use the 3 nearest neighbor classifier to create the learnign curve
sklearn_model = KNeighborsClassifier(n_neighbors=3)
feat_lc_df = feature_learning_curve(data_df, sklearn_model, sklearn_metric)
# Out:
# KNEIGHBORSCLASSIFIER
# ['R' '(B-R)/C' 'R-(G+B)/2' 'B-R' 'W/H' '(R+G+B)/3' 'R-G' 'B-(G+R)/2'
#  '(R-G)/C' 'M=maxRGB' '(G-B)/C' 'G' 'H' 'G-B' 'W' 'G-(R+B)/2' 'W*H'
#  'C=M-m' 'm=minRGB' 'C/V' 'B']

# %%
# Plot the learning curve
plt.errorbar(feat_lc_df.index+1, feat_lc_df['perf_tr'], yerr=feat_lc_df['std_tr'], label='Training set')
plt.errorbar(feat_lc_df.index+1, feat_lc_df['perf_te'], yerr=feat_lc_df['std_te'], label='Test set')
plt.xticks(np.arange(1, 22, 1)) 
plt.xlabel('Number of features')
plt.ylabel(sklearn_metric.__name__)
plt.legend(loc='lower right')

# %% [markdown]
# We see the, with 5 features, it is about as good as it gets, given the error bars.

# %% [markdown]
# ### Singular Value Decomposition
# Let us move now to the second way of reducing dimensionality: feature transforms.
# When we use SVD, the feature transform consists in finding the "principal directions"(directions of largest variance). The method is also known as Pricipal Component Analysis (PCA). I simply used my search engine and typed the keywords "pandas svd". I found a nice tutorial on <a href="https://machinelearningmastery.com/singular-value-decomposition-for-machine-learning/">this page</a> and a step-by-step procedure on <a href="https://cmdlinetips.com/2019/05/singular-value-decomposition-svd-in-python/">this page</a>.
#
# We will guide you step-by-step:
# * Create a dataframe called `df_scaled` containing the standardized columns, except the last one (tip: just use `drop` to eliminate the last column).
# * Perform a singular value decomposition of `df_scaled` and call the resulting matrices u, s, v.
# * Make a scree plot of the eigen values (square of the singular values). Save the plot in file 'svd_scree_plot.png'.
# * Create a new dataframe `svd_df` with the two singular values as columns and the fruit type as index.
# * Make pairwise scatter plots of the three first singular values.
#
# Then the question to answer will be to compute the performances obtained with the 3 nearest neighbor method using the first 3 singular values.

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>

# %%
# Make use the CS scaled dataset (this should be already loaded in data_df,
# if you did things correctly in previous questions)
# To obtain df_scaled, remove the last column of data_df.

df_scaled = data_df.iloc[:, :-1]

df_scaled.head()
# Out:
#           R         G         B  M=maxRGB  m=minRGB     C=M-m  R-(G+B)/2  \
# 0 -0.094697 -0.802912  1.418747 -0.891020  1.336466 -1.696950  -0.432637
# 1  0.503616 -0.772561 -0.666665  0.183203 -0.913998  0.879247   1.148003
# 2  0.061006 -1.398826 -2.104806 -0.741563 -2.119769  1.269262   1.765190
# 3 -1.726425  0.099504 -0.595447 -0.333516 -0.686620  0.349539  -1.302076
# 4 -0.060727  1.399374  1.787878  1.139418  1.806535 -0.746776  -1.604870
#
#         G-B  G-(R+B)/2       B-R  ...       R-G   (G-B)/C   (B-R)/C   (R-G)/C  \
# 0 -1.660362  -1.347004  1.210587  ...  0.579199 -2.336012  0.646130  1.179120
# 1 -0.029340  -0.573507 -0.898534  ...  1.031343 -0.629588 -0.462186  0.866252
# 2  0.639794  -0.241299 -1.738912  ...  1.189200 -0.096683 -0.983712  0.919732
# 3  0.529659   1.114701  0.760168  ... -1.457199  0.582662  1.098479 -1.379813
# 4 -0.394783   0.394178  1.483473  ... -1.189423  0.414910  1.919623 -1.962907
#
#    (R+G+B)/3       C/V         W         H       W/H       W*H
# 0   0.326008 -1.650431  0.249030  0.065306 -0.126039 -0.032573
# 1  -0.499504  0.938614  0.278258 -0.273339  0.449690 -0.190080
# 2  -1.801489  1.726784  2.273420  1.076728  0.157238  1.436246
# 3  -1.107018  0.552259 -0.145793 -0.563028  0.591975 -0.426325
# 4   1.630251 -0.909639 -1.142907 -1.194313  1.109809 -0.814331
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Perform singular value decomposition

# %%
u, s, v = np.linalg.svd(df_scaled, full_matrices=True)
print('U {}'.format(u.shape))
print('S {}'.format(s.shape))
print('V {}'.format(v.shape))
# Out:
# U (491, 491)
# S (21,)
# V (21, 21)

# %% [markdown]
# #### Make a scree plot
# This plot allows us to decide how many components to keep, considering the total variance explained.

# %%
var_explained = np.round(s**2/np.sum(s**2), decimals=3)
sns.barplot(x=list(range(1,len(var_explained)+1)),
            y=var_explained, color="limegreen")
plt.xlabel('SVs', fontsize=16)
plt.ylabel('Percent Variance Explained', fontsize=16)
plt.savefig('svd_scree_plot.png',dpi=100)

# %% [markdown]
# We see that after 3 features there is a big drop in variance. So tentatively, let us keep the top three components.

# %% [markdown]
# #### Pairplot

# %%
# Create a dataframe with only the three first principal components
fruit_name = ['Banana', 'Apple']
fruit_list = [fruit_name[int((i+1)/2)] for i in df["fruit"].tolist()]
fnum=3
labels= ['SV'+str(i) for i in range(1,fnum+1)]
df_3svd = pd.DataFrame(u[:,0:fnum], columns=labels)
df_3svd['fruit'] = fruit_list
df_3svd.head()
# Out:
#         SV1       SV2       SV3  fruit
# 0 -0.082698  0.020103  0.011550  Apple
# 1  0.022860  0.032317  0.033502  Apple
# 2  0.063949  0.088905 -0.001070  Apple
# 3  0.011986 -0.031958 -0.060016  Apple
# 4 -0.045156 -0.092459 -0.008405  Apple

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>

# %%
# Show the pairplot of svd_df
g = sns.pairplot(df_3svd, hue="fruit", markers=["o", "s"], diag_kind="hist")

# %% [markdown]
# #### Evaluate df_3svd:
# This piece of code will serve you later to answer question 5!

# %%
# We use the function df_cross_validate that we already used in question 3 to evaluate svd_df
df_3svd['fruit'] = df.iloc[:, -1].to_numpy() # We replace the target values by numbers
p_tr, s_tr, p_te, s_te = df_cross_validate(df_3svd, sklearn_model, sklearn_metric)
metric_name = sklearn_metric.__name__.upper()
print("AVERAGE TRAINING {0:s} +- STD: {1:.2f} +- {2:.2f}".format(metric_name, p_tr, s_tr))
print("AVERAGE TEST {0:s} +- STD: {1:.2f} +- {2:.2f}".format(metric_name, p_te, s_te))
# Out:
# AVERAGE TRAINING BALANCED_ACCURACY_SCORE +- STD: 0.86 +- 0.02
# AVERAGE TEST BALANCED_ACCURACY_SCORE +- STD: 0.76 +- 0.02

# %% [markdown]
# #### SVD learning curve:

# %%
# We compute the learning curve for the 3-nearest neighbor classifier ...
sklearn_model = KNeighborsClassifier(n_neighbors=3)
feat_lc_df = svd_learning_curve(data_df, sklearn_model, sklearn_metric)

# and we plot the learning curve
plt.errorbar(feat_lc_df.index+1, feat_lc_df['perf_tr'], yerr=feat_lc_df['std_tr'], label='Training set')
plt.errorbar(feat_lc_df.index+1, feat_lc_df['perf_te'], yerr=feat_lc_df['std_te'], label='Test set')
plt.xticks(np.arange(1, 22, 1)) 
plt.xlabel('Number of principal compoments')
plt.ylabel(sklearn_metric.__name__)
plt.legend(loc='lower right')
# Out:
# KNEIGHBORSCLASSIFIER

# %% [markdown]
# #### Comparison of dimensionality reduction methods

# %% [markdown]
# Even though features 4 and 5 did not seem to explain a lot of additional variance, there seems to be an optimum at 4 or 5 features. Compare the performances of df_5feat and df_5svd (with 5 top components). Is one significantly better then the other?

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>

# %%
df_5svd = df_3svd # Replace with the correct dataframe having 5 principal components

# Put here the code to compute the performances of df_5feat and df_5svd
fnum=5
labels= ['SV'+str(i) for i in range(1,fnum+1)]
df_5svd = pd.DataFrame(u[:,0:fnum], columns=labels)
df_5svd['fruit'] = df.iloc[:, -1].to_numpy() # Need numeric values
p_tr_5svd, s_tr_5svd, p_te_5svd, s_te_5svd = 0,0,0,0 # REPLACE THIS
p_tr_5feat, s_tr_5feat, p_te_5feat, s_te_5feat = 0,0,0,0 # REPLACE THIS

print("5FEAT AVERAGE TRAINING {0:s} +- STD: {1:.2f} +- {2:.2f}".format(metric_name, p_tr_5feat, s_tr_5feat))
print("5FEAT AVERAGE TEST {0:s} +- STD: {1:.2f} +- {2:.2f}".format(metric_name, p_te_5feat, s_te_5feat))
print("5SVD AVERAGE TRAINING {0:s} +- STD: {1:.2f} +- {2:.2f}".format(metric_name, p_tr_5svd, s_tr_5svd))
print("5SVD AVERAGE TEST {0:s} +- STD: {1:.2f} +- {2:.2f}".format(metric_name, p_te_5svd, s_te_5svd))
# Out:
# 5FEAT AVERAGE TRAINING BALANCED_ACCURACY_SCORE +- STD: 0.00 +- 0.00
# 5FEAT AVERAGE TEST BALANCED_ACCURACY_SCORE +- STD: 0.00 +- 0.00
# 5SVD AVERAGE TRAINING BALANCED_ACCURACY_SCORE +- STD: 0.00 +- 0.00
# 5SVD AVERAGE TEST BALANCED_ACCURACY_SCORE +- STD: 0.00 +- 0.00

# %%
#Does one method give significantly better results than the other?
answer = 1 # One for yes and 0 for no

# This is the checker code, keep it
question = 5
answer = 0.001*(p_te_5feat-p_te_5svd)/(s_te_5feat+s_te_5svd)
score += check(answer, question)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-72-c518e0687094> in <module>
#       4 # This is the checker code, keep it
#       5 question = 5
# ----> 6 answer = 0.001*(p_te_5feat-p_te_5svd)/(s_te_5feat+s_te_5svd)
#       7 score += check(answer, question)
#
# ZeroDivisionError: float division by zero

# %%
print('Your final score is %d / 5, congratulations!' % score)
# Out:
# Your final score is 3 / 5, congratulations!

# %% [markdown]
# <div style="background:#FFFFAA">
# <span style="color:red">
# <br>
#     To finalize your homework:
# <b>
# <ul>
#     <li> Use  Kernel + Restart and Run all.</li>
#     <li> Save your notebook.</li>
#     <li> Push your changes to your GitHub repo with:</li>
# </ul>
# </b>
# <pre>
# git add .
# git commit -m 'my homework is done'
# git push
# </pre>
# <br>
# </span>
# </div>
